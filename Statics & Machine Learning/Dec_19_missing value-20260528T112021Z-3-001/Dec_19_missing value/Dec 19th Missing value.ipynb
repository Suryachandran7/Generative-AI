# %%
#Dec_19th Missing Value

# %%
import os
import numpy as np
import pandas as pd 
import warnings
warnings.filterwarnings("ignore")
os.getcwd()
# Out:
# 'C:\\Users\\User\\Desktop\\Batch Dec12th Stats ML\\Dec_19 missing value outliers'

# %%
df=pd.read_excel("preprocessing_1.xlsx")
df.head()
# Out:
#   Dept   Age  Experience  Salary       Education
# 0   HR  32.0         9.0   35000  Under_Graduate
# 1   HR  33.0        12.0   48000          Master
# 2   IT  35.0        12.0   45000          Master
# 3   IT  36.0        12.0   67000        Graduate
# 4   HR  34.0        11.0   36000             NaN

# %%
# how to find the missing value
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dept        20 non-null     object
#  1   Age         20 non-null     float64
#  2   Experience  18 non-null     float64
#  3   Salary      22 non-null     int64
#  4   Education   20 non-null     object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1008.0+ bytes

# %%
# there is missing value in Dept, Age,Experience and Education

# %%
df.dtypes
# Out:
# Dept           object
# Age           float64
# Experience    float64
# Salary          int64
# Education      object
# dtype: object

# %%
df.describe()
# Out:
#              Age  Experience         Salary
# count  20.000000   18.000000      22.000000
# mean   37.950000   13.416667   45386.363636
# std    11.085671    9.440604   24449.136618
# min    20.000000    2.000000   22000.000000
# 25%    32.000000   10.250000   36000.000000
# 50%    34.500000   12.000000   40500.000000
# 75%    42.750000   13.000000   45000.000000
# max    70.000000   40.000000  145500.000000

# %%
df.describe(include="O")
# Out:
#        Dept Education
# count    20        20
# unique    4         3
# top      HR    Master
# freq      8         9

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.boxplot(df["Salary"])
# Out:
# <AxesSubplot:xlabel='Salary'>

# %%
sns.boxplot(df["Age"])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
# missing value
df.isnull().any
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.any of      Dept    Age  Experience  Salary  Education
# 0   False  False       False   False      False
# 1   False  False       False   False      False
# 2   False  False       False   False      False
# 3   False  False       False   False      False
# 4   False  False       False   False       True
# 5   False  False       False   False      False
# 6   False   True       False   False      False
# 7   False  False       False   False      False
# 8   False  False        True   False      False
# 9   False  False       False   False      False
# 10  False  False        True   False      False
# 11   True  False       False   False      False
# 12   True  False       False   False      False
# 13  False  False       False   False       True
# 14  False  False        True   False      False
# 15  False   True        True   False      False
# 16  False  False       False   False      False
# ...

# %%
df.isnull().any()
# Out:
# Dept           True
# Age            True
# Experience     True
# Salary        False
# Education      True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Dept          2
# Age           2
# Experience    4
# Salary        0
# Education     2
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 10

# %%
# finding percentage of missing value in column
df.isnull().sum()/len(df)*100
# Out:
# Dept           9.090909
# Age            9.090909
# Experience    18.181818
# Salary         0.000000
# Education      9.090909
# dtype: float64

# %%
# both isna() and isnull() functions are used to find the missing value

# %%
df1=df.copy()

# %%
df1.head(100)
# Out:
#          Dept    Age  Experience  Salary       Education
# 0          HR  32.00    9.000000   35000  Under_Graduate
# 1          HR  33.00   12.000000   48000          Master
# 2          IT  35.00   12.000000   45000          Master
# 3          IT  36.00   12.000000   67000        Graduate
# 4          HR  34.00   11.000000   36000          Master
# 5          IT  33.00   13.000000   42000        Graduate
# 6   Marketing  37.95   12.000000   39000          Master
# 7          HR  32.00   10.000000   42000          Master
# 8   Marketing  31.00   13.416667   36000  Under_Graduate
# 9          IT  45.00   14.000000   45000          Master
# 10      Sales  50.00   13.416667   46000          Master
# 11         HR  70.00   40.000000  145500        Graduate
# 12         HR  29.00    8.500000   38000        Graduate
# 13         HR  32.00   11.000000   39000          Master
# 14      Sales  38.00   13.416667   35000          Master
# ...

# %%
df1.tail(10)
# Out:
#          Dept    Age  Experience  Salary       Education
# 12         HR  29.00    8.500000   38000        Graduate
# 13         HR  32.00   11.000000   39000          Master
# 14      Sales  38.00   13.416667   35000          Master
# 15         HR  37.95   13.416667   32000  Under_Graduate
# 16         IT  42.00   14.000000   42000        Graduate
# 17  Marketing  50.00   13.000000   39000          Master
# 18         HR  38.00   11.000000   42000        Graduate
# 19         HR  20.00    2.000000   22000  Under_Graduate
# 20         IT  52.00   35.000000   60000          Master
# 21      Sales  27.00    2.000000   23000  Under_Graduate

# %%
# handling misssing value
#applying mean approach

# %%
df1["Age"]=df1["Age"].fillna(df1["Age"].mean())

# %%
df1["Experience"]=df1["Experience"].fillna(df1["Experience"].mean())

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dept        20 non-null     object
#  1   Age         22 non-null     float64
#  2   Experience  22 non-null     float64
#  3   Salary      22 non-null     int64
#  4   Education   20 non-null     object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1008.0+ bytes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dept        20 non-null     object
#  1   Age         20 non-null     float64
#  2   Experience  18 non-null     float64
#  3   Salary      22 non-null     int64
#  4   Education   20 non-null     object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1008.0+ bytes

# %%
# we can handle missing value by 
# applying median approach also
#df1["Age"]=df1["Age"].fillna(df1["Age"].median())
##df1["Experience"]=df1["Experience"].fillna(df1["Experience"].median())

# %%
# handling missing value of categorical columns
# mode approach

# %%
df1["Education"]=df1["Education"].fillna(df1["Education"].mode()[0])

# %%
df1["Dept"]=df1["Dept"].fillna(df1["Dept"].mode()[0])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dept        22 non-null     object
#  1   Age         22 non-null     float64
#  2   Experience  22 non-null     float64
#  3   Salary      22 non-null     int64
#  4   Education   22 non-null     object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1008.0+ bytes

# %%
# there is no missing value
