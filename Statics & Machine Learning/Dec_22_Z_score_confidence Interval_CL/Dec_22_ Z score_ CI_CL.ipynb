# %%
#Pandas DataFrames
import pandas as pd
import numpy as np
import scipy.stats as st

# %%
data=np.array([6,7,7,12,13,13,15,16,19,22])
st.zscore(data)
# Out:
# array([-1.39443338, -1.19522861, -1.19522861, -0.19920477,  0.        ,
#         0.        ,  0.39840954,  0.5976143 ,  1.19522861,  1.79284291])

# %%
data1=np.array([[5,6,7,7,8],
              [8,8,8,9,8],
              [2,2,4,4,5]])

# %%
st.zscore(data1)
# Out:
# array([[ 0.        ,  0.26726124,  0.39223227,  0.16222142,  0.70710678],
#        [ 1.22474487,  1.06904497,  0.98058068,  1.13554995,  0.70710678],
#        [-1.22474487, -1.33630621, -1.37281295, -1.29777137, -1.41421356]])

# %%
cardio=pd.read_csv("Cardio_vascular.csv")
cardio.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
cardio1=cardio.copy()
cardio1.head()
cardio1
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
cardio2=st.zscore(cardio1)

# %%
cardio2
# Out:
#            age       sex        cp  trestbps      chol       fbs   restecg  \
# 0    -0.268674  0.661504 -0.915755 -0.377636 -0.659332 -0.418878  0.891255
# 1    -0.158385  0.661504 -0.915755  0.479107 -0.833861  2.387330 -1.004049
# 2     1.716520  0.661504 -0.915755  0.764688 -1.396233 -0.418878  0.891255
# 3     0.723923  0.661504 -0.915755  0.936037 -0.833861 -0.418878  0.891255
# 4     0.834212 -1.511706 -0.915755  0.364875  0.930822  2.387330  0.891255
# ...        ...       ...       ...       ...       ...       ...       ...
# 1020  0.503346  0.661504  0.055931  0.479107 -0.484803 -0.418878  0.891255
# 1021  0.613635  0.661504 -0.915755 -0.377636  0.232705 -0.418878 -1.004049
# 1022 -0.820116  0.661504 -0.915755 -1.234378  0.562371 -0.418878 -1.004049
# 1023 -0.489251 -1.511706 -0.915755 -1.234378  0.155137 -0.418878 -1.004049
# 1024 -0.048097  0.661504 -0.915755 -0.663216 -1.124743 -0.418878  0.891255
#
# ...

# %%
st.norm.interval(alpha=0.95,loc=np.mean(cardio["chol"]),scale=st.sem(cardio["chol"]))
# Out:
# (242.8415586477306, 249.1584413522694)

# %%
#st.norm.interval(alpha=0.95,loc=250,scale=10)
# Out:
# (230.40036015459947, 269.59963984540053)

# %%
st.norm.interval(alpha=0.95,loc=np.mean(cardio["trestbps"]),scale=st.sem(cardio["trestbps"]))
# Out:
# (130.5393515374625, 132.68406309668387)

# %%
st.norm.interval(alpha=0.99,loc=np.mean(cardio["chol"]),scale=st.sem(cardio["chol"]))
# Out:
# (241.8491044463629, 250.1508955536371)

# %%
# using t score calculating the CI

# %%
data5=[12,12,13,13,15,16,17,22,23,25,26,27,28,28,29]

# %%
st.t.interval(alpha=0.95,df=len(data5)-1,loc=np.mean(data5),scale=st.sem(data5))
# Out:
# (16.75776979778498, 24.042230202215016)

# %%
len(data5)
# Out:
# 15
