# %%
#Dec 14 Visualization

# %%
import numpy as np # linear algebra
import pandas as pd # data processing , reading the csv file (pd.read_csv)

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
#in jupyter notebook perfect display of plot inside the notebook.
import warnings
warnings.filterwarnings("ignore")

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\User\\Desktop\\Batch Dec12th Stats ML\\Dec 14th visualization_continue'

# %%
data=pd.read_csv("HR_Employee_Attrition_Data1.csv")

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
empdf=data.copy()
empdf.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
empdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
pd.set_option("display.max_columns",100)

# %%
empdf.head(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# ...

# %%
empdf.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  EnvironmentSatisfaction Gender  HourlyRate  \
# 1465            2061                        3   Male          41
# ...

# %%
#countplot plot the count of the number of records by category

# %%
#gender distribution
plt.figure(figsize=(10,6))
sns.countplot(x=empdf["Gender"])
plt.title("Distribution of Gender in the company")
plt.show()

# %%
# as per observation there are approx 600 no female & 900 no of male employees.

# %%
#business travel distribution
plt.figure(figsize=(10,6))
sns.countplot(x=empdf["BusinessTravel"])
plt.title("Distribution of BusinessTravel in the company")
plt.show()

# %%
#department distribution
plt.figure(figsize=(10,6))
sns.countplot(x=empdf["Department"],hue=empdf["Gender"])
plt.title("Distribution of Department in the company")
plt.show()

# %%
#work life balance distribution
plt.figure(figsize=(10,6))
sns.countplot(x=empdf["WorkLifeBalance"])
plt.title("Distribution of work life balance in the company")
plt.show()

# %%
#work life balance distribution
plt.figure(figsize=(10,6))
sns.countplot(x=empdf["MonthlyRate"])
plt.title("Distribution of work life balance in the company")
plt.show()

# %%
#gender distribution as per Attrition
plt.figure(figsize=(10,6))
sns.countplot(x=empdf["Gender"],hue=empdf["Attrition"])
plt.title("Attriction level based on gender")
plt.show()

# %%
#gender distribution as per Attrition
plt.figure(figsize=(10,6))
sns.countplot(x=empdf["Gender"],hue=empdf["MaritalStatus"],palette=sns.color_palette("RdBu"))
plt.title("MaritalStatus level based on gender")
plt.show()

# %%
#gender distribution as per Attrition
plt.figure(figsize=(10,6))
sns.countplot(x=empdf["MaritalStatus"],hue=empdf["Attrition"])
plt.title("Attriction level based on MartialStatus")
plt.show()

# %%
plt.subplots(1,3,figsize=(20,10))

plt.subplot(1,3,1)

sns.countplot(x=empdf["MaritalStatus"],hue=empdf["Attrition"])
plt.title("Attriction level based on MartialStatus")

plt.subplot(1,3,2)

sns.countplot(x=empdf["Gender"],hue=empdf["MaritalStatus"],palette=sns.color_palette("RdBu"))
plt.title("MaritalStatus level based on gender")

plt.subplot(1,3,3)

sns.countplot(x=empdf["Gender"],hue=empdf["MaritalStatus"],palette=sns.color_palette("RdBu"))
plt.title("MaritalStatus level based on gender")




plt.show()

# %% [markdown]
# # BAR PLOT

# %%
# bar plot or bar chart represents how a numerical variable relates to a categorical variables

# %%
plt.figure(figsize=(14,6))
ax=sns.barplot(data=empdf,x="EducationField",y="MonthlyRate")

# %%
plt.figure(figsize=(14,6))

ax=sns.barplot(x=empdf["EducationField"],y=empdf["MonthlyRate"])
ax.set(ylabel="MONTHLYRATE")
plt.ylabel("MONTHLYRATE",fontsize=20)
plt.show()

# %%
plt.figure(figsize=(14,6))

ax=sns.barplot(x=empdf["EducationField"],y=empdf["MonthlyRate"],hue="Gender",data=empdf)
ax.set(ylabel="MONTHLYRATE")
plt.ylabel("MONTHLYRATE",fontsize=20)
plt.show()

# %%
plt.figure(figsize=(14,6))

ax=sns.barplot(x=empdf["EducationField"],y=empdf["MonthlyRate"],hue="JobRole",data=empdf)
ax.set(ylabel="MONTHLYRATE")
plt.ylabel("MONTHLYRATE",fontsize=20)
plt.show()

# %%
empdf["WorkLifeBalance"].value_counts()
# Out:
# 3    893
# 2    344
# 4    153
# 1     80
# Name: WorkLifeBalance, dtype: int64

# %%
empdf["Gender"].value_counts()
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %% [markdown]
# # histogram or histplot

# %%
# monthly income feature distribution
plt.figure(figsize=(10,6))
sns.histplot(x=empdf["MonthlyIncome"],color="magenta")
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='Count'>

# %%
# monthly income feature distribution
plt.figure(figsize=(10,6))
sns.histplot(empdf["Gender"],color="magenta")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Count'>

# %%
# monthly income feature distribution
plt.figure(figsize=(10,6))
sns.histplot(empdf["MonthlyIncome"],kde=True)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='Count'>

# %%
plt.figure(figsize=(10,6))
sns.histplot(x="Department",kde=False,hue="Gender",data=empdf)
# Out:
# <AxesSubplot:xlabel='Department', ylabel='Count'>

# %%
plt.figure(figsize=(10,6))
sns.histplot(x="Department",kde=False,data=empdf,stat="probability")
# Out:
# <AxesSubplot:xlabel='Department', ylabel='Probability'>

# %%
plt.figure(figsize=(10,6))
sns.histplot(x="Department",kde=False,data=empdf)
# Out:
# <AxesSubplot:xlabel='Department', ylabel='Count'>

# %%
plt.figure(figsize=(10,6))
sns.histplot(x="Department",kde=False,data=empdf,stat="density")
# Out:
# <AxesSubplot:xlabel='Department', ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
sns.histplot(x="Age",kde=True,data=empdf,stat="density")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
sns.histplot(x="Age",kde=True,data=empdf,stat="density",bins=10)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
sns.histplot(x="Age",kde=True,data=empdf,stat="density",bins=5)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
sns.histplot(x="Age",kde=True,data=empdf,stat="density",binwidth=3)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
sns.histplot(x="Age",kde=True,data=empdf,stat="density",binwidth=8)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
sns.histplot(x="EducationField",kde=True,data=empdf,stat="density")
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
sns.histplot(x="EducationField",kde=True,data=empdf,stat="density",bins=10)
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='Density'>

# %% [markdown]
# # lineplot

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x="Age",data=empdf,y="JobSatisfaction",dashes=False,ci=None)
plt.title("LINEPLOT")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x="Age",data=empdf,y="JobSatisfaction",dashes=False)
plt.title("LINEPLOT")
plt.show()

# %%
empdf.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
# pie chart
plt.figure(figsize=(16,10))
plt.pie(x=empdf["Attrition"].value_counts(),labels=empdf["Attrition"].value_counts().index,autopct="%0.2f%%")
plt.show()

# %%
plt.figure(figsize=(16,10))
plt.pie(x=empdf["Attrition"].value_counts(),labels=empdf["Attrition"].value_counts())
plt.title("important")
plt.show()

# %%
# pie chart
plt.figure(figsize=(16,10))
plt.pie(x=empdf["Department"].value_counts(),labels=empdf["Department"].value_counts().index,autopct="%0.2f%%")
plt.show()

# %%
# Boxplot

# %%
plt.figure(figsize=(16,10))
sns.boxplot(data=empdf)
# Out:
# <AxesSubplot:>

# %%
df1=pd.read_csv("Cardio_vascular.csv")
df1.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
plt.figure(figsize=(16,10))
sns.boxplot(data=df1)
# Out:
# <AxesSubplot:>

# %%
# calculation correlations

corr=df1.corr()
corr
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.103574 -0.071960  0.271001  0.219832  0.121163
# sex      -0.103574  1.000000 -0.041119 -0.078974 -0.198258  0.027200
# cp       -0.071960 -0.041119  1.000000  0.038177 -0.081641  0.079294
# trestbps  0.271001 -0.078974  0.038177  1.000000  0.127977  0.181767
# chol      0.219832 -0.198258 -0.081641  0.127977  1.000000  0.026917
# fbs       0.121163  0.027200  0.079294  0.181767  0.026917  1.000000
# restecg  -0.132515 -0.055117  0.043581 -0.123794 -0.147410 -0.104051
# thalach  -0.390854 -0.048612  0.305959 -0.038721 -0.020588 -0.009370
# exang     0.088017  0.139157 -0.401513  0.061197  0.067382  0.049261
# oldpeak   0.208159  0.084687 -0.174733  0.187434  0.064880  0.010859
# slope    -0.168905 -0.026666  0.131633 -0.120445 -0.014248 -0.061902
# ca        0.271415  0.111729 -0.176206  0.104554  0.074259  0.137156
# thal      0.072191  0.198424 -0.163341  0.059276  0.100244 -0.042177
# ...

# %%
# calculation correlations
plt.figure(figsize=(16,10))
corr=df1.corr()
sns.heatmap((corr))
# Out:
# <AxesSubplot:>

# %%
# calculation correlations
plt.figure(figsize=(16,10))
corr=df1.corr()
sns.heatmap((corr),annot=True)
# Out:
# <AxesSubplot:>
